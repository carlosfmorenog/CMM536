# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosfmorenog/CMM536/blob/master/CMM536_Topic_1/CMM536_T1_Lec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to CMM536 - Advanced Data Science!

# %% [markdown]
# ## Before we start...
# 1. Attendance (Attendr)
# 2. Moodle
#     1. Resources ([Trello](https://trello.com/b/ll10VrHI/cmm536-resources))
#     1. Reinforcement courses ([Datacamp](https://www.datacamp.com/groups/shared_links/dbf81d95c39f83410ca5ab579663fe403c3456b8b8df1be1cb10b44967d7e1b4))
#     1. Office Hours ([AskRGU](ask.rgu.ac.uk))

# %% [markdown]
# ## Assesment Information

# %% [markdown]
# One coursework (individual):
#
#     - Date o Submission: TBC

# %% [markdown]
# Next week, we will have a coursework clarification session

# %% [markdown]
# ## But first...
#
# Go to [menti.com](http://www.menti.com), enter the code that you will be shown in the screen and answer the questions

# %% [markdown]
# # Introduction to Jupyter Notebook

# %% [markdown]
# An easy to use tool to run and present (mostly) Python code

# %% [markdown]
# This session will help you understand how to install it, use it and better work with it for the purpose of this module!

# %% [markdown]
# ### Installing Python & Jupyter Notebook

# %% [markdown]
# Remember, Python is the programming language; Jupyter Notebook is the Integrated Development Environment (IDE)!

# %% [markdown]
# Therefore you need to first install the language, and then to look for the suitable IDE...

# %% [markdown]
# Or you can install everything in one bundle called [Anaconda](https://www.anaconda.com/)

# %% [markdown]
# I have added Resources in [Trello Board](https://trello.com/b/ll10VrHI) for installation help in different platforms

# %% [markdown]
# #### Anaconda Demo

# %% [markdown]
# ### Types of cells

# %% [markdown]
# #### Code Cells

# %% [markdown]
# In these cells you put your Python Code

# %% [markdown]
# You will recognise them easily, as they have a [ ] next to them (and a play button when you hover over)

# %%
1+1
# Out:
# 2

# %% [markdown]
# #### Markdown Cells

# %% [markdown]
# In these cells you can write comments, section headers, or even import some media!

# %% [markdown]
# Since you will be presenting your coursework as a Jupyter Notebook, I recommend you to have a very good idea of how to use the Markdown cells

# %% [markdown]
# You can check [this post](https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd) for the "ultimate" guide on how to use markdown

# %% [markdown]
# ### Spell Check

# %% [markdown]
# A necessary feature for *everyone*!

# %% [markdown]
#     - pip install jupyter_contrib_nbextensions
#     - jupyter contrib nbextension install --user
#     - jupyter nbextension enable spellchecker/main

# %% [markdown]
# ### Keyboard Shortcuts

# %% [markdown]
# Having an idea of the shortcuts will help you produce notebooks faster!

# %% [markdown]
# Check your shortcuts in Help -> Keyboard Shortcuts

# %% [markdown]
# For instance, you can press "B" and add a cell below (instead of going to the menu!

# %% [markdown]
# ## Loading images/videos into a Jupyter Notebook

# %% [markdown]
# For Google Colab, it is recommended that you include images from the sharable link of your Google Drive!

# %% [markdown]
# Inserting an image online (make sure you have access always)
#
#   ![Fig 3.](web address)
# ![Fig 3.](https://www.abc.net.au/news/image/12035942-3x2-940x627.jpg)

# %% [markdown]
# Loading an image AS DATA, you can use packages such as `OpenCV` or `Pillow` (we will use this a lot during the module!)

# %% [markdown]
# Inserting a YouTube Video:
#
#     1. Go to YouTube
#     2. Under "Share" select embed
#     3. You will get an html code, copy it inside the following code

# %% [markdown]
#     from IPython.display import HTML
#     HTML('embed html code here')

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/r-uOLxNrNk8" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/r-uOLxNrNk8" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Loading data into a Google Colab + GitHub Jupyter Notebook

# %% [markdown]
# **YOU CAN LOAD DATA DIRECTLY FROM YOUR GITHUB REPO INTO THIS COLAB NOTEBOOK! FIRST, YOU NEED TO CLONE YOUR GITHUB REPO INTO THE NOTEBOOK (MAKE SURE THAT THE GITHUB REPO IS PUBLIC, LIKE MINE)**

# %%
# !git clone https://github.com/carlosfmorenog/CMM536  # clone repo
# Out:
# Cloning into 'CMM536'...
# remote: Enumerating objects: 484, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 484 (delta 19), reused 28 (delta 7), pack-reused 427
# Receiving objects: 100% (484/484), 133.21 MiB | 23.49 MiB/s, done.
# Resolving deltas: 100% (199/199), done.

# %% [markdown]
# **Now you will notice that if you click on the folder icon on the left, the repository CMM536 is included as part of the data of this notebook! Simply load the data by using the correct path:**

# %%
import pandas as pd
data_git2 = pd.read_csv('/content/CMM536/CMM536_Topic_1/data.csv')
data_git2
# Out:
#        Col 1  Col 2  Col 3
# 0       Nick     22   1.85
# 1      Chris     29   1.79
# 2        Tim     28   1.75
# 3        Ron     34   1.81
# 4     Monica     35   1.69
# 5  Cassandra     21   1.66

# %% [markdown]
# This way, you can now load the image as data:

# %%
from PIL import Image
im = Image.open("/content/CMM536/CMM536_Topic_1/test.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x250 at 0x7F53B6E08E50>

# %% [markdown]
# # "Lab 1": Installing Python and Jupyter Notebook (or Anaconda) + Checking Online Notebook Options
