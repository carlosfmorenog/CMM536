# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosfmorenog/CMM536/blob/master/CMM536_Topic_1/CMM536_T1_Lec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to CMM536 - Advanced Data Science!
# * Dr Carlos Moreno-García
# * Associate Professor | Research Degrees Co-coordinator
# * c.moreno-garcia@rgu.ac.uk

# %% [markdown]
# ## Before we start...
# 1. Attendance ([Attendr](https://www.attendr.app/))
# 2. Moodle
#     1. Resources ([Trello](https://trello.com/invite/b/6663e78cf32911673157f28d/ATTIafa39509acdc60b9e0da5361505d8be170987772/cmm536-resources))
#     1. Reinforcement courses ([Datacamp](https://www.datacamp.com/groups/shared_links/63840bf8043fe7f0558599282a5e955807f2543485e2530480e3d2f87471fb34) and [LinkedIn Learning](https://learning.linkedin.com/cx/get-started?src=go-pa&trk=sem-ga_campid.21301455341_asid.163286450155_crid.699771780912_kw.linkedin%20learning_d.c_tid.kwd-296672886869_n.g_mt.b_geo.20339&mcid=7198411097454903346&cid=&gad_source=1&gclid=Cj0KCQiA1p28BhCBARIsADP9HrMrPs2t-a6nOitDaAm0C7b7f1M_r5A3Z5Xtt8Hannw9LB2HX_Krl-QaAtdmEALw_wcB&gclsrc=aw.ds))
#     1. Office Hours (Monday and Thursday 10-11 am, please book as they are subject to change)

# %% [markdown]
# ## Assesment Information

# %% [markdown]
# One coursework, 100% of your mark

# %% [markdown]
# Date of submission: 22$^{nd}$ April, 2026 at 1 pm

# %% [markdown]
# **Next week, we will have a coursework clarification session during lab time!**

# %% [markdown]
# ## But first...
#
# Go to [menti.com](http://www.menti.com), enter the code that you will be shown in the screen and answer the questions

# %% [markdown]
# ## Introduction to Jupyter Notebook

# %% [markdown]
# An easy to use tool to run and present (mostly) Python code

# %% [markdown]
# This session will help you understand how to install it, use it and better work with it for the purpose of this module!

# %% [markdown]
# ### Installing Python & Jupyter Notebook

# %% [markdown]
# Remember, Python is the programming language; Jupyter Notebook is the Integrated Development Environment (IDE)!

# %% [markdown]
# Therefore you need to first install the language, and then to look for the suitable IDE...

# %% [markdown]
# Or you can install everything in one bundle called [Anaconda](https://www.anaconda.com/)

# %% [markdown]
# I have added Resources in our [Trello](https://trello.com/b/ll10VrHI) board for installation help in different platforms

# %% [markdown]
# #### Anaconda Demo

# %% [markdown]
# ### Types of cells

# %% [markdown]
# #### Code Cells

# %% [markdown]
# In these cells you put your Python Code

# %% [markdown]
# You will recognise them easily, as they have an In[] next to them

# %%
1+1
# Out:
# 2

# %% [markdown]
# #### Markdown Cells

# %% [markdown]
# In these cells you can write comments, section headers, or even import some media!

# %% [markdown]
# Since you will be presenting your coursework as a Jupyter Notebook, I recommend you to have a very good idea of how to use the Markdown cells

# %% [markdown]
# You can check [this post](https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd) for the "ultimate" guide on how to use markdown

# %% [markdown]
# ### Keyboard Shortcuts

# %% [markdown]
# Having an idea of the shortcuts will help you produce notebooks faster!

# %% [markdown]
# Check your shortcuts in Tools $\rightarrow$ Keyboard Shortcuts, or press `Ctrl + M H`

# %% [markdown]
# For instance, you can press `Ctrl + M B` to add a cell below

# %% [markdown]
# ## Loading images/videos into a Jupyter Notebook (Google Colab with GitHub version)

# %% [markdown]
# There's a button at the top of the editor that allows you to upload images to Markdown cells. **Be careful, as it creates an extremely long link in your cell!**

# %% [markdown]
# Inserting an image online (make sure you have access always)
#
# ![Fig 1.](https://i.kym-cdn.com/entries/icons/facebook/000/021/464/14608107_1180665285312703_1558693314_n.jpg)
#
# **Double-click the image to see the code that allows you to insert the image**

# %% [markdown]
# Loading an image AS DATA, you can use packages such as `OpenCV` or `Pillow` (we will use this a lot during the module!)

# %% [markdown]
# If you are working with GitHub, it is easier to **clone the repository** using the code in the following cell

# %%
# !git clone https://github.com/carlosfmorenog/CMM536
# Out:
# Cloning into 'CMM536'...
# remote: Enumerating objects: 847, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 847 (delta 43), reused 15 (delta 4), pack-reused 734 (from 2)
# Receiving objects: 100% (847/847), 161.16 MiB | 20.08 MiB/s, done.
# Resolving deltas: 100% (341/341), done.

# %%
# This cell will work only if the "test.jpg" is in the same directory as this notebook
from PIL import Image
im = Image.open("/content/CMM536/CMM536_Topic_1/test.jpg") # notice the change in the image directory
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=681x445>

# %%
# the variable im contains the pixels of the image
im.size
# Out:
# (681, 445)

# %% [markdown]
# **Inserting a YouTube Video:**
#
#     1. Go to YouTube
#     2. Under "Share" select embed
#     3. You will get an html code, copy it inside the following Python code
#
#         from IPython.display import HTML
#         HTML('embed html code here')

# %%
import warnings;
warnings.simplefilter('ignore')
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/r-uOLxNrNk8?si=g_tnbcTaCi7SJ6Uo" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/r-uOLxNrNk8?si=g_tnbcTaCi7SJ6Uo" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## Loading data into a Jupyter Notebook

# %% [markdown]
# Just as we loaded the image as data before, you must know that we can load data from different extensions (.csv, .tsv, .txt, .xlsx) to our notebooks!

# %% [markdown]
# The easiest way to do so is with a Python module called `Pandas`

# %%
import pandas as pd

# %%
# This cell will work only if the "data.csv" is in the same directory as this notebook
data = pd.read_csv('/content/CMM536/CMM536_Topic_1/data.csv') # again, load file and address correctly
data
# Out:
#        Col 1  Col 2  Col 3
# 0       Nick     22   1.85
# 1      Chris     29   1.79
# 2        Tim     28   1.75
# 3        Ron     34   1.81
# 4     Monica     35   1.69
# 5  Cassandra     21   1.66

# %% [markdown]
# Commands such as `read_csv` can also take a web address as an input, and load images from online repos!

# %% [markdown]
# For instance, if `data.csv` is in my [Dropbox](https://www.dropbox.com/), I can copy the dropbox link, change `dl=0` for `raw=1` and load the file

# %%
# From dropbox
data_dropbox = pd.read_csv('https://www.dropbox.com/scl/fi/w1536ewswdqr1z5g0e4b9/data.csv?rlkey=k6d8b9sfobwp1jdd1639nwu6t&raw=1')
data_dropbox
# Out:
#        Col 1  Col 2  Col 3
# 0       Nick     21   1.85
# 1      Chris     29   1.79
# 2        Tim     28   1.75
# 3        Ron     34   1.81
# 4     Monica     35   1.69
# 5  Cassandra     21   1.66

# %% [markdown]
# ## Online Jupyter Notebooks
#
# Each version is different, as it teaches you different ways to import data depending on the platform. I recommend you check **ALL** of them!

# %% [markdown]
# ### Google Colab
# https://colab.research.google.com/drive/1v_cSGbwUEiLY6DNubeYpB8plDTTJfoLS?usp=sharing

# %% [markdown]
# ### Kaggle
# https://www.kaggle.com/carlosmorenogarcia/cmm536-t1-lec-ipynb

# %% [markdown]
# # "Lab 1": Installing Python and Jupyter Notebook (or Anaconda) + Checking Online Notebook Options
